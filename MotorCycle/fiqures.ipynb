# %%
import matplotlib.pyplot as plt
import numpy as np

# مدل‌ها
models = ['Logistic Regression', 'XGBoost', 'SVM', 'Random Forest', 'Decision Tree', 'DBC']

# داده‌های هر متود برای هر معیار
methods_data = {
    'Simple': {
        'accuracy': [0.98, 0.98, 0.98, 0.98, 0.98, 0.94],
        'precision': [0.76, 0.75, 0.74, 0.78, 0.67, 0.82],
        'recall': [0.66, 0.73, 0.63, 0.54, 0.55, 0.96],
        'f1_score': [0.70, 0.74, 0.67, 0.63, 0.60, 0.85]
    },
    'After Calibration': {
        'accuracy': [0.97, 0.97, 0.98, 0.97, 0.98, 0.94],
        'precision': [0.58, 0.56, 0.68, 0.61, 0.71, 0.82],
        'recall': [0.92, 0.95, 0.82, 0.82, 0.54, 0.96],
        'f1_score': [0.72, 0.70, 0.74, 0.70, 0.61, 0.85]
    },
    'After ClusterCentroids': {
        'accuracy': [0.73, 0.90, 0.63, 0.91, 0.93, 0.94],
        'precision': [0.10, 0.25, 0.07, 0.25, 0.31, 0.82],
        'recall': [1.00, 0.99, 1.00, 0.99, 0.98, 0.96],
        'f1_score': [0.18, 0.40, 0.13, 0.40, 0.47, 0.85]
    },
    'After TomekLinks': {
        'accuracy': [0.98, 0.98, 0.98, 0.98, 0.98, 0.94],
        'precision': [0.75, 0.73, 0.73, 0.74, 0.67, 0.82],
        'recall': [0.69, 0.71, 0.72, 0.59, 0.66, 0.96],
        'f1_score': [0.72, 0.71, 0.72, 0.65, 0.66, 0.85]
    },
    'After RandomUnderSampler': {
        'accuracy': [0.94, 0.96, 0.95, 0.95, 0.94, 0.94],
        'precision': [0.35, 0.45, 0.35, 0.41, 0.37, 0.82],
        'recall': [0.98, 0.97, 0.98, 0.97, 0.94, 0.96],
        'f1_score': [0.52, 0.62, 0.52, 0.57, 0.53, 0.85]
    },
    'After SMOTE': {
        'accuracy': [0.95, 0.96, 0.96, 0.97, 0.96, 0.94],
        'precision': [0.41, 0.49, 0.43, 0.50, 0.47, 0.82],
        'recall': [0.92, 0.87, 0.88, 0.89, 0.89, 0.96],
        'f1_score': [0.56, 0.62, 0.58, 0.64, 0.61, 0.85]
    },
    'After ADASYN': {
        'accuracy': [0.95, 0.96, 0.96, 0.97, 0.97, 0.94],
        'precision': [0.40, 0.46, 0.42, 0.49, 0.47, 0.82],
        'recall': [0.93, 0.87, 0.86, 0.89, 0.88, 0.96],
        'f1_score': [0.56, 0.60, 0.57, 0.64, 0.62, 0.85]
    },
    'After RandomOverSampling': {
        'accuracy': [0.96, 0.98, 0.97, 0.97, 0.97, 0.94],
        'precision': [0.48, 0.62, 0.55, 0.67, 0.69, 0.82],
        'recall': [0.97, 0.83, 0.94, 0.61, 0.55, 0.96],
        'f1_score': [0.64, 0.71, 0.69, 0.63, 0.61, 0.85]
    },
}

# رسم نمودار برای هر متود
for method, metrics in methods_data.items():
    fig, ax = plt.subplots(figsize=(10, 6))

    bar_width = 0.2
    index = np.arange(len(models))

    # رسم نوارها برای هر معیار
    bar1 = ax.barh(index, metrics['accuracy'], bar_width, label='Accuracy')
    bar2 = ax.barh(index + bar_width, metrics['precision'], bar_width, label='Precision')
    bar3 = ax.barh(index + 2 * bar_width, metrics['recall'], bar_width, label='Recall')
    bar4 = ax.barh(index + 3 * bar_width, metrics['f1_score'], bar_width, label='F1-Score')

    # تنظیمات نمودار
    ax.set_xlabel('Scores')
    ax.set_title(f'Model Comparison ({method} Method)')
    ax.set_yticks(index + 1.5 * bar_width)
    ax.set_yticklabels(models)
    ax.legend()

    # نمایش مقادیر روی نوارها
    for bars in [bar1, bar2, bar3, bar4]:
        for bar in bars:
            ax.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f'{bar.get_width():.2f}', 
                    va='center', ha='left')

    # نمایش نمودار
    plt.tight_layout()
    plt.show()
