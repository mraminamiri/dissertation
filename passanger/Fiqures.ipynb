# %%
import matplotlib.pyplot as plt
import numpy as np

# مدل‌ها
models = ['Logistic Regression', 'XGBoost', 'SVM', 'Random Forest', 'Decision Tree', 'DBC']

# داده‌های هر متود برای هر معیار
methods_data = {
    'Simple': {
        'accuracy': [0.98, 0.98, 0.99, 0.98, 0.98, 0.97],
        'precision': [0.77, 0.69, 0.79, 0.70, 0.59, 0.71],
        'recall': [0.53, 0.64, 0.51, 0.51, 0.55, 0.95],
        'f1_score': [0.63, 0.66, 0.62, 0.58, 0.57, 0.77]
    },
    'After Calibration': {
        'accuracy': [0.98, 0.98, 0.98, 0.98, 0.98, 0.97],
        'precision': [0.50, 0.48, 0.64, 0.54, 0.63, 0.71],
        'recall': [0.93, 0.94, 0.72, 0.80, 0.50, 0.95],
        'f1_score': [0.65, 0.63, 0.68, 0.64, 0.56, 0.77]
    },
    'After ClusterCentroids': {
        'accuracy': [0.78, 0.88, 0.67, 0.93, 0.85, 0.97],
        'precision': [0.07, 0.14, 0.05, 0.20, 0.12, 0.71],
        'recall': [0.99, 0.99, 0.99, 0.99, 0.99, 0.95],
        'f1_score': [0.13, 0.24, 0.10, 0.33, 0.21, 0.77]
    },
    'After TomekLinks': {
        'accuracy': [0.98, 0.98, 0.98, 0.98, 0.98, 0.97],
        'precision': [0.73, 0.68, 0.79, 0.71, 0.57, 0.71],
        'recall': [0.55, 0.60, 0.51, 0.51, 0.55, 0.95],
        'f1_score': [0.62, 0.63, 0.62, 0.59, 0.56, 0.77]
    },
    'After RandomUnderSampler': {
        'accuracy': [0.92, 0.96, 0.94, 0.95, 0.93, 0.97],
        'precision': [0.18, 0.35, 0.23, 0.26, 0.21, 0.71],
        'recall': [0.98, 0.97, 0.98, 0.97, 0.94, 0.95],
        'f1_score': [0.31, 0.51, 0.37, 0.41, 0.34, 0.77]
    },
    'After SMOTE': {
        'accuracy': [0.96, 0.97, 0.97, 0.98, 0.97, 0.97],
        'precision': [0.30, 0.39, 0.33, 0.42, 0.39, 0.71],
        'recall': [0.88, 0.82, 0.73, 0.87, 0.84, 0.95],
        'f1_score': [0.44, 0.53, 0.46, 0.56, 0.53, 0.77]
    },
    'After ADASYN': {
        'accuracy': [0.96, 0.97, 0.97, 0.97, 0.97, 0.97],
        'precision': [0.29, 0.38, 0.34, 0.41, 0.38, 0.71],
        'recall': [0.88, 0.82, 0.73, 0.85, 0.83, 0.95],
        'f1_score': [0.44, 0.52, 0.46, 0.55, 0.52, 0.77]
    },
    'After RandomOverSampling': {
        'accuracy': [0.96, 0.98, 0.98, 0.98, 0.98, 0.97],
        'precision': [0.32, 0.55, 0.48, 0.66, 0.60, 0.71],
        'recall': [0.97, 0.77, 0.92, 0.59, 0.53, 0.95],
        'f1_score': [0.48, 0.64, 0.63, 0.62, 0.56, 0.77]
    },
}

# رسم نمودار برای هر متود
for method, metrics in methods_data.items():
    fig, ax = plt.subplots(figsize=(10, 6))

    bar_width = 0.2
    index = np.arange(len(models))

    # رسم نوارها برای هر معیار
    bar1 = ax.barh(index, metrics['accuracy'], bar_width, label='Accuracy')
    bar2 = ax.barh(index + bar_width, metrics['precision'], bar_width, label='Precision')
    bar3 = ax.barh(index + 2 * bar_width, metrics['recall'], bar_width, label='Recall')
    bar4 = ax.barh(index + 3 * bar_width, metrics['f1_score'], bar_width, label='F1-Score')

    # تنظیمات نمودار
    ax.set_xlabel('Scores')
    ax.set_title(f'Model Comparison ({method} Method)')
    ax.set_yticks(index + 1.5 * bar_width)
    ax.set_yticklabels(models)
    ax.legend()

    # نمایش مقادیر روی نوارها
    for bars in [bar1, bar2, bar3, bar4]:
        for bar in bars:
            ax.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f'{bar.get_width():.2f}', 
                    va='center', ha='left')

    # نمایش نمودار
    plt.tight_layout()
    plt.show()
